# %% [markdown]
# <H1>My Jupyter Notebook on IBM Watson Studio<H1>

# %% [markdown]
# <b>Richard Mora<b>

# %% [markdown]
# Student

# %% [markdown]
# _I am interested in data science because I want to learn how the machine learning could change the world._

# %% [markdown]
# <H3>The sum of two numbers<H3>

# %%
def sum(a, b):
    return a+b;
print(sum(1,2))
# Out:
# 3

# %% [markdown]
# 1. [link text](https://cdn.forbes.co/2020/05/Data-scientist-Getty-Images-1280720.jpg)
# 2. This is a message
# - This is the second message
